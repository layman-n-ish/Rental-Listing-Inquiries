# %%
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
train_df = pd.read_json("data/train.json")
test_df = pd.read_json("data/test.json")
train_df['features'].head()
# Out:
# 10                                                       []
# 100004    [Laundry In Building, Dishwasher, Hardwood Flo...
# 100007                            [Hardwood Floors, No Fee]
# 100014                                                   []
# 100026    [Cats Allowed, Dogs Allowed, Elevator, Laundry...
# Name: features, dtype: object

# %%
def feature_engineering(df, flag, b_dict={}, m_dict={}):

    ulimit = np.percentile(df.price.values, 99)
    df['price'].loc[df.price > ulimit] = ulimit

    llimit = np.percentile(df.latitude.values, 1)
    ulimit = np.percentile(df.latitude.values, 99)
    df['latitude'].loc[df.latitude < llimit] = llimit
    df['latitude'].loc[df.latitude > ulimit] = ulimit

    llimit = np.percentile(df.longitude.values, 1)
    ulimit = np.percentile(df.longitude.values, 99)
    df['longitude'].loc[df.longitude < llimit] = llimit
    df['longitude'].loc[df.longitude > ulimit] = ulimit
    
    df["created"] = pd.to_datetime(df["created"])
    df["created_year"] = df["created"].dt.year
    df["created_month"] = df["created"].dt.month
    df["created_day"] = df["created"].dt.day
    df["created_hour"] = df["created"].dt.hour
    df["is_night"] = 1*(df["created_hour"] <= 7)
    df["created_weekday"] = df["created"].dt.weekday
    df["is_weekend"] = 1*(df["created_weekday"] > 5)
    
    df["total_rooms"] = df["bedrooms"] + df["bathrooms"]
    df['price_per_bed'] = df['price']/(df['bedrooms']+1)
    df['price_per_bath'] = df['price']/(df['bathrooms']+1)
    df["price_per_room"] = df['price']/(df['total_rooms']+1)
    
    df['description'] = df['description'].str.replace('<[^<>]+>', ' ')
    df['description'] = df['description'].str.replace('[0-9]+', 'num')
    df['description'] = df['description'].str.lower().replace('[^a-zA-Z0-9]', ' ')
    for i in df.index:
        df.loc[i, 'len_description'] = len(df.loc[i, 'description'])
        df.loc[i, 'num_features'] = len(df.loc[i, 'features'])

    

    if not flag:
        interest_dummies = pd.get_dummies(df.interest_level)
        df_dumm = pd.concat([df,interest_dummies[['low','medium','high']]], axis = 1).drop('interest_level', axis = 1)

        df_n = df_dumm[['building_id', 'manager_id', 'low', 'high', 'medium']]
        df_n_m = df_n.groupby(df_n.manager_id).mean()
        df_n_b = df_n.groupby(df_n.building_id).mean()

        df_n_m['manager_skill'] = df_n_m['low']*0+ df_n_m['medium']*1 + df_n_m['high']*2
        df_n_b['build_popularity'] = df_n_b['low']*0+ df_n_b['medium']*1 + df_n_b['high']*2

        df_n_m.drop(['low', 'high', 'medium'], axis=1)
        df_n_b.drop(['low', 'high', 'medium'], axis=1)
        b_dict = df_n_b.to_dict()
        m_dict = df_n_m.to_dict() 

    for i in range(df.shape[0]):
        if df.loc[df.index[i], 'building_id'] in b_dict['build_popularity']:
            df.loc[df.index[i], 'building_popularity'] = b_dict['build_popularity'][df.loc[df.index[i], 'building_id']]
        else:
            df.loc[df.index[i], 'building_popularity'] = 0.33453255354249495 #bp_mean
    
        if df.loc[df.index[i], 'manager_id'] in m_dict['manager_skill']:
            df.loc[df.index[i], 'manager_skill'] = m_dict['manager_skill'][df.loc[df.index[i], 'manager_id']]
        else:
            df.loc[df.index[i], 'manager_skill'] = 0.3666338439324288 #ms_mean
    df["logprice"] = np.log(df["price"])

    num_feats = ["bathrooms", "bedrooms", "latitude", "longitude", "price", "num_features", 
    "len_description","created_year", "created_month", "created_day", "created_hour", "created_weekday", 
    "is_night", "is_weekend", "price_per_bed", "price_per_bath", "total_rooms", "price_per_room",
    "manager_skill", "building_popularity", "description", "features"]
    X = df[num_feats]
    return [X, b_dict, m_dict]
train, b_dict, m_dict = feature_engineering(df=train_df,flag=0)
test, b_dict, m_dict = feature_engineering(df=test_df,flag=1, b_dict = b_dict,m_dict =  m_dict)
train["logprice"] = np.log(train_df["price"])
test["logprice"] = np.log(test_df["price"])
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
# test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 

# train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
# test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

# train_df['price_per_room'] = train_df['price']/train_df['room_sum']
# test_df['price_per_room'] = test_df['price']/test_df['room_sum']

# train_df["num_photos"] = train_df["photos"].apply(len)
# test_df["num_photos"] = test_df["photos"].apply(len)

# train_df["num_features"] = train_df["features"].apply(len)
# test_df["num_features"] = test_df["features"].apply(len)

# train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
# test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# %%
# train_df["created"] = pd.to_datetime(train_df["created"])
# test_df["created"] = pd.to_datetime(test_df["created"])
# train_df["created_year"] = train_df["created"].dt.year
# test_df["created_year"] = test_df["created"].dt.year
# train_df["created_month"] = train_df["created"].dt.month
# test_df["created_month"] = test_df["created"].dt.month
# train_df["created_day"] = train_df["created"].dt.day
# test_df["created_day"] = test_df["created"].dt.day
# train_df["created_hour"] = train_df["created"].dt.hour
# test_df["created_hour"] = test_df["created"].dt.hour

# %%
train["pos"] = train_df.longitude.round(3).astype(str) + '_' + train_df.latitude.round(3).astype(str)
test["pos"] = test_df.longitude.round(3).astype(str) + '_' + test_df.latitude.round(3).astype(str)

vals = train['pos'].value_counts()
dvals = vals.to_dict()
train["density"] = train['pos'].apply(lambda x: dvals.get(x, vals.min()))
test["density"] = test['pos'].apply(lambda x: dvals.get(x, vals.min()))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price", "num_features", 
    "len_description","created_year", "created_month", "created_day", "created_hour", "created_weekday", 
    "is_night", "is_weekend", "price_per_bed", "price_per_bath", "total_rooms", "price_per_room",
    "manager_skill", "building_popularity", "logprice", "density"]

# %%
# index=list(range(train_df.shape[0]))
# random.shuffle(index)
# a=[np.nan]*len(train_df)
# b=[np.nan]*len(train_df)
# c=[np.nan]*len(train_df)

# %%
# a=[]
# b=[]
# c=[]
# building_level={}
# for j in train_df['manager_id'].values:
#     building_level[j]=[0,0,0]

# for j in range(train_df.shape[0]):
#     temp=train_df.iloc[j]
#     if temp['interest_level']=='low':
#         building_level[temp['manager_id']][0]+=1
#     if temp['interest_level']=='medium':
#         building_level[temp['manager_id']][1]+=1
#     if temp['interest_level']=='high':
#         building_level[temp['manager_id']][2]+=1

# for i in test_df['manager_id'].values:
#     if i not in building_level.keys():
#         a.append(np.nan)
#         b.append(np.nan)
#         c.append(np.nan)
#     else:
#         a.append(building_level[i][0]*1.0/sum(building_level[i]))
#         b.append(building_level[i][1]*1.0/sum(building_level[i]))
#         c.append(building_level[i][2]*1.0/sum(building_level[i]))
# test_df['manager_level_low']=a
# test_df['manager_level_medium']=b
# test_df['manager_level_high']=c

# %%
# train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39481 entries, 10 to 99994
# Data columns (total 31 columns):
# bathrooms                39481 non-null float64
# bedrooms                 39481 non-null int64
# building_id              39481 non-null object
# created                  39481 non-null datetime64[ns]
# description              39481 non-null object
# display_address          39481 non-null object
# features                 39481 non-null object
# interest_level           39481 non-null object
# latitude                 39481 non-null float64
# listing_id               39481 non-null int64
# longitude                39481 non-null float64
# manager_id               39481 non-null object
# photos                   39481 non-null object
# price                    39481 non-null int64
# street_address           39481 non-null object
# logprice                 39481 non-null float64
# price_t                  39481 non-null float64
# room_sum                 39481 non-null float64
# price_per_room           39481 non-null float64
# num_photos               39481 non-null int64
# num_features             39481 non-null int64
# num_description_words    39481 non-null int64
# created_year             39481 non-null int64
# created_month            39481 non-null int64
# created_day              39481 non-null int64
# created_hour             39481 non-null int64
# pos                      39481 non-null object
# density                  39481 non-null int64
# manager_level_low        38276 non-null float64
# manager_level_medium     38276 non-null float64
# manager_level_high       38276 non-null float64
# dtypes: datetime64[ns](1), float64(10), int64(11), object(9)
# memory usage: 9.6+ MB

# %%
# index=list(range(train_df.shape[0]))
# random.shuffle(index)
# a=[np.nan]*len(train_df)
# b=[np.nan]*len(train_df)
# c=[np.nan]*len(train_df)
# for i in range(5):
#     building_level={}
#     for j in train_df['building_id'].values:
#         building_level[j]=[0,0,0]
    
#     test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
#     train_index=list(set(index).difference(test_index))
    
#     for j in train_index:
#         temp=train_df.iloc[j]
#         if temp['interest_level']=='low':
#             building_level[temp['building_id']][0]+=1
#         if temp['interest_level']=='medium':
#             building_level[temp['building_id']][1]+=1
#         if temp['interest_level']=='high':
#             building_level[temp['building_id']][2]+=1
            
#     for j in test_index:
#         temp=train_df.iloc[j]
#         if sum(building_level[temp['building_id']])!=0:
#             a[j]=building_level[temp['building_id']][0]*1.0/sum(building_level[temp['building_id']])
#             b[j]=building_level[temp['building_id']][1]*1.0/sum(building_level[temp['building_id']])
#             c[j]=building_level[temp['building_id']][2]*1.0/sum(building_level[temp['building_id']])
            
# train_df['building_level_low']=a
# train_df['building_level_medium']=b
# train_df['building_level_high']=c


# train_df.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100014        2.0         4  38a913e46c94a7f46ddf19b756a9640c
# 100026        1.0         1  a7efbeb58190aa267b4a9121cd0c88c0
#
#                    created                                        description  \
# 10     2016-06-24 07:54:24  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 100004 2016-04-17 03:26:41  Top Top West Village location, beautiful Pre-w...
# 100007 2016-04-18 02:22:02  Building Amenities - Garage - Garden - fitness...
# 100014 2016-04-19 04:24:47
# 100026 2016-04-20 02:36:35                           <p><a  website_redacted
#
#             display_address  \
# 10      Metropolitan Avenue
# 100004          W 13 Street
# 100007     East 49th Street
# 100014     West 18th Street
# 100026     Hamilton Terrace
#
#                                                  features interest_level  \
# 10                                                     []         medium
# 100004  [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 100007                          [Hardwood Floors, No Fee]            low
# 100014                                                 []         medium
# 100026  [Cats Allowed, Dogs Allowed, Elevator, Laundry...         medium
#
#         latitude  listing_id         ...           created_day created_hour  \
# 10       40.7145       34633         ...                    24            7
# 100004   40.7388        6727         ...                    17            3
# 100007   40.7539       38446         ...                    18            2
# 100014   40.7429        2808         ...                    19            4
# 100026   40.8234       21731         ...                    20            2
#
#                    pos  density manager_level_low  manager_level_medium  \
# 10      -73.942_40.714        4          0.745763              0.254237
# 100004  -74.002_40.739       70          0.595238              0.357143
# 100007  -73.968_40.754      117          0.808511              0.141844
# 100014  -74.003_40.743       23          0.890625              0.101562
# 100026  -73.946_40.823       32          0.600000              0.218182
#
#         manager_level_high  building_level_low  building_level_medium  \
# 10                0.000000            1.000000               0.000000
# 100004            0.047619            0.470588               0.382353
# 100007            0.049645            0.901408               0.098592
# 100014            0.007812            0.400000               0.600000
# 100026            0.181818            0.176471               0.529412
#
#         building_level_high
# 10                 0.000000
# 100004             0.147059
# 100007             0.000000
# 100014             0.000000
# 100026             0.294118
#
# [5 rows x 34 columns]

# %%
# a=[]
# b=[]
# c=[]
# building_level={}
# for j in train_df['building_id'].values:
#     building_level[j]=[0,0,0]

# for j in range(train_df.shape[0]):
#     temp=train_df.iloc[j]
#     if temp['interest_level']=='low':
#         building_level[temp['building_id']][0]+=1
#     if temp['interest_level']=='medium':
#         building_level[temp['building_id']][1]+=1
#     if temp['interest_level']=='high':
#         building_level[temp['building_id']][2]+=1

# for i in test_df['building_id'].values:
#     if i not in building_level.keys():
#         a.append(np.nan)
#         b.append(np.nan)
#         c.append(np.nan)
#     else:
#         a.append(building_level[i][0]*1.0/sum(building_level[i]))
#         b.append(building_level[i][1]*1.0/sum(building_level[i]))
#         c.append(building_level[i][2]*1.0/sum(building_level[i]))
# test_df['building_level_low']=a
# test_df['building_level_medium']=b
# test_df['building_level_high']=c

# %%
# features_to_use.append('manager_level_low') 
# features_to_use.append('manager_level_medium') 
# features_to_use.append('manager_level_high')
# features_to_use.append('building_level_low') 
# features_to_use.append('building_level_medium') 
# features_to_use.append('building_level_high')

# %%
train['description'] = train_df['description'].str.replace('<[^<>]+>', ' ')
train['description'] = train_df['description'].str.replace('[0-9]+', 'num')
train['description'] = train_df['description'].str.lower().replace('[^a-zA-Z0-9]', ' ', regex=True)
test['description'] = test_df['description'].str.replace('<[^<>]+>', ' ')
test['description'] = test_df['description'].str.replace('[0-9]+', 'num')
test['description'] = test_df['description'].str.lower().replace('[^a-zA-Z0-9]', ' ', regex=True)
# from textblob import TextBlob
# train_df['sentiment_polarity'] = train_df['description'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
# train_df['sentiment_subjectivity'] = train_df['description'].apply(lambda x: TextBlob(str(x)).sentiment.subjectivity)
# test_df['sentiment_polarity'] = test_df['description'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
# test_df['sentiment_subjectivity'] = test_df['description'].apply(lambda x: TextBlob(str(x)).sentiment.subjectivity)
# features_to_use.append('sentiment_polarity') 
# features_to_use.append('sentiment_subjectivity')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# categorical = ["display_address", "manager_id", "building_id"]
# for f in categorical:
#         if train_df[f].dtype=='object':
#             lbl = LabelEncoder()
#             lbl.fit(list(train_df[f].values) + list(test_df[f].values))
#             train_df[f] = lbl.transform(list(train_df[f].values))
#             test_df[f] = lbl.transform(list(test_df[f].values))
#             features_to_use.append(f)

train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

# %%
train['features'] = train_df['features']
test['features'] = test_df['features']
# train.head()
# train.to_csv("train_all_feat.csv", index = False)
# test.to_csv("test_all_feat.csv", index = False)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price", "num_features", 
    "len_description","created_year", "created_month", "created_day", "created_hour", "created_weekday", 
    "is_night", "is_weekend", "price_per_bed", "price_per_bath", "total_rooms", "price_per_room",
    "manager_skill", "building_popularity", "logprice", "density"]
count_features = CountVectorizer(stop_words='english', max_features=500,ngram_range=(1,4))
count_features_train_sparse = count_features.fit_transform(train["features"])
count_features_test_sparse = count_features.transform(test["features"])

train_X = sparse.hstack([train[features_to_use], count_features_train_sparse]).tocsr()
test_X = sparse.hstack([test[features_to_use], count_features_test_sparse]).tocsr()

tfidf_features = TfidfVectorizer(stop_words='english', max_features=500,ngram_range=(1,4))
tfidf_features_train_sparse = count_features.fit_transform(train_df["features"])
tfidf_features_test_sparse = count_features.transform(test_df["features"])

train_X = sparse.hstack([train_X, tfidf_features_train_sparse]).tocsr()
test_X = sparse.hstack([test_X, tfidf_features_test_sparse]).tocsr()

# %%
count_desc = CountVectorizer(stop_words='english', max_features=500,ngram_range=(1,4))
count_desc_train_sparse = count_desc.fit_transform(train_df["description"])
count_desc_test_sparse = count_desc.transform(test_df["description"])

train_X = sparse.hstack([train_X, count_desc_train_sparse]).tocsr()
test_X = sparse.hstack([test_X, count_desc_test_sparse]).tocsr()

tfidf_desc = CountVectorizer(stop_words='english', max_features=500,ngram_range=(1,4))
tfidf_desc_train_sparse = tfidf_desc.fit_transform(train_df["description"])
tfidf_desc_test_sparse = tfidf_desc.transform(test_df["description"])

train_X = sparse.hstack([train_X, tfidf_desc_train_sparse]).tocsr()
test_X = sparse.hstack([test_X, tfidf_desc_test_sparse]).tocsr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-01af35ca7c68> in <module>()
#      13 test_X = sparse.hstack([test_X, tfidf_desc_test_sparse]).tocsr()
#      14
# ---> 15 print(train_X.head())
#
# /usr/local/lib/python3.5/dist-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     684             return self.getnnz()
#     685         else:
# --> 686             raise AttributeError(attr + " not found")
#     687
#     688     def transpose(self, axes=None, copy=False):
#
# AttributeError: head not found

# %%
print(train_X[0:5])
# Out:
#   (0, 0)	1.5
#   (0, 1)	3.0
#   (0, 2)	40.7145
#   (0, 3)	-73.9425
#   (0, 4)	3000.0
#   (0, 6)	561.0
#   (0, 7)	2016.0
#   (0, 8)	6.0
#   (0, 9)	24.0
#   (0, 10)	7.0
#   (0, 11)	4.0
#   (0, 12)	1.0
#   (0, 14)	750.0
#   (0, 15)	1200.0
#   (0, 16)	4.5
#   (0, 17)	545.4545454545455
#   (0, 18)	0.2647058823529412
#   (0, 19)	0.5
#   (0, 20)	8.006367567650246
#   (0, 21)	4.0
#   (0, 1027)	1.0
#   (0, 1036)	1.0
#   (0, 1037)	1.0
#   (0, 1039)	1.0
#   (0, 1040)	1.0
#   :	:
#   (4, 17)	575.0
#   (4, 18)	0.6527777777777778
#   (4, 19)	1.1
#   (4, 20)	7.45298232946546
#   (4, 21)	32.0
#   (4, 27)	1.0
#   (4, 28)	1.0
#   (4, 31)	1.0
#   (4, 87)	1.0
#   (4, 95)	1.0
#   (4, 154)	1.0
#   (4, 191)	1.0
#   (4, 309)	1.0
#   (4, 527)	1.0
#   (4, 528)	1.0
#   (4, 531)	1.0
#   (4, 587)	1.0
#   (4, 595)	1.0
#   (4, 654)	1.0
#   (4, 691)	1.0
#   (4, 809)	1.0
#   (4, 1508)	1.0
#   (4, 2008)	1.0
#   (4, 2508)	1.0
#   (4, 3008)	1.0

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=321, num_rounds=1300):
    param = {'booster': 'gbtree',
              #'objective': 'multi:softmax',
              'objective': 'multi:softprob',
              'eval_metric': 'mlogloss',
              'gamma': 1,
              'min_child_weight': 1.5,
              'max_depth': 5,
              'lambda': 10,
              'subsample': 0.7,
              'colsample_bytree': 0.7,
              'colsample_bylevel': 0.7,
              'eta': 0.03,
              'tree_method': 'exact',
              'seed': 2017,
              'nthread': 12,
              "num_class":3
              }
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
# preds, model = runXGB(train_X, train_y, test_X, num_rounds=1300)
# out_df = pd.DataFrame(preds)
# out_df.columns = ["high", "medium", "low"]
# out_df["listing_id"] = test_df.listing_id.values
# out_df.to_csv("sub51.csv", index=False)

# %%
# out_df.head()
# Out:
#        high    medium       low  listing_id
# 0  0.000679  0.007194  0.992127        5529
# 1  0.001685  0.008177  0.990138       14597
# 2  0.003122  0.042709  0.954170       43396
# 3  0.008244  0.061525  0.930231       25538
# 4  0.000808  0.123692  0.875500       26644

# %%
from sklearn.model_selection import KFold
cv_scores = []
kf = KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
#         print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.07489	test-mlogloss:1.07511
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.05194	test-mlogloss:1.05246
# [2]	train-mlogloss:1.03034	test-mlogloss:1.03123
# [3]	train-mlogloss:1.00968	test-mlogloss:1.01089
# [4]	train-mlogloss:0.989035	test-mlogloss:0.990525
# [5]	train-mlogloss:0.969713	test-mlogloss:0.971506
# [6]	train-mlogloss:0.952411	test-mlogloss:0.954472
# [7]	train-mlogloss:0.934486	test-mlogloss:0.936744
# [8]	train-mlogloss:0.916897	test-mlogloss:0.919403
# [9]	train-mlogloss:0.903303	test-mlogloss:0.906016
# [10]	train-mlogloss:0.887589	test-mlogloss:0.890473
# [11]	train-mlogloss:0.87258	test-mlogloss:0.875668
# [12]	train-mlogloss:0.860634	test-mlogloss:0.863916
# [13]	train-mlogloss:0.847956	test-mlogloss:0.851458
# [14]	train-mlogloss:0.83487	test-mlogloss:0.838607
# [15]	train-mlogloss:0.822853	test-mlogloss:0.826759
# [16]	train-mlogloss:0.810342	test-mlogloss:0.814427
# [17]	train-mlogloss:0.797797	test-mlogloss:0.802042
# [18]	train-mlogloss:0.786169	test-mlogloss:0.790621
# [19]	train-mlogloss:0.774604	test-mlogloss:0.779217
# [20]	train-mlogloss:0.764984	test-mlogloss:0.769863
# [21]	train-mlogloss:0.754726	test-mlogloss:0.759738
# [22]	train-mlogloss:0.745315	test-mlogloss:0.750567
# [23]	train-mlogloss:0.735917	test-mlogloss:0.741396
# [24]	train-mlogloss:0.726904	test-mlogloss:0.732517
# [25]	train-mlogloss:0.7183	test-mlogloss:0.724029
# [26]	train-mlogloss:0.709882	test-mlogloss:0.715792
# [27]	train-mlogloss:0.701907	test-mlogloss:0.70798
# [28]	train-mlogloss:0.694395	test-mlogloss:0.700656
# [29]	train-mlogloss:0.686727	test-mlogloss:0.693178
# [30]	train-mlogloss:0.67929	test-mlogloss:0.685878
# [31]	train-mlogloss:0.671703	test-mlogloss:0.678373
# [32]	train-mlogloss:0.664727	test-mlogloss:0.671526
# [33]	train-mlogloss:0.659221	test-mlogloss:0.666163
# [34]	train-mlogloss:0.652788	test-mlogloss:0.659818
# [35]	train-mlogloss:0.647207	test-mlogloss:0.654379
# [36]	train-mlogloss:0.640909	test-mlogloss:0.64823
# [37]	train-mlogloss:0.635707	test-mlogloss:0.643144
# [38]	train-mlogloss:0.630084	test-mlogloss:0.637694
# [39]	train-mlogloss:0.624435	test-mlogloss:0.632142
# [40]	train-mlogloss:0.619437	test-mlogloss:0.62736
# [41]	train-mlogloss:0.614077	test-mlogloss:0.622106
# [42]	train-mlogloss:0.609393	test-mlogloss:0.617526
# [43]	train-mlogloss:0.605157	test-mlogloss:0.613331
# [44]	train-mlogloss:0.600392	test-mlogloss:0.608718
# [45]	train-mlogloss:0.59612	test-mlogloss:0.604595
# [46]	train-mlogloss:0.592085	test-mlogloss:0.600658
# [47]	train-mlogloss:0.588137	test-mlogloss:0.596837
# [48]	train-mlogloss:0.584316	test-mlogloss:0.593152
# [49]	train-mlogloss:0.580174	test-mlogloss:0.58918
# [50]	train-mlogloss:0.575984	test-mlogloss:0.58514
# [51]	train-mlogloss:0.572018	test-mlogloss:0.581324
# [52]	train-mlogloss:0.568085	test-mlogloss:0.577435
# [53]	train-mlogloss:0.565294	test-mlogloss:0.574729
# [54]	train-mlogloss:0.56222	test-mlogloss:0.571834
# [55]	train-mlogloss:0.558855	test-mlogloss:0.568539
# [56]	train-mlogloss:0.555403	test-mlogloss:0.565198
# [57]	train-mlogloss:0.552398	test-mlogloss:0.562283
# [58]	train-mlogloss:0.549178	test-mlogloss:0.55918
# [59]	train-mlogloss:0.545837	test-mlogloss:0.555921
# [60]	train-mlogloss:0.543088	test-mlogloss:0.553267
# [61]	train-mlogloss:0.540648	test-mlogloss:0.550936
# [62]	train-mlogloss:0.538115	test-mlogloss:0.548613
# [63]	train-mlogloss:0.535265	test-mlogloss:0.545892
# [64]	train-mlogloss:0.532803	test-mlogloss:0.543543
# [65]	train-mlogloss:0.530538	test-mlogloss:0.54142
# [66]	train-mlogloss:0.528418	test-mlogloss:0.539409
# [67]	train-mlogloss:0.525654	test-mlogloss:0.5367
# [68]	train-mlogloss:0.523365	test-mlogloss:0.534574
# [69]	train-mlogloss:0.521111	test-mlogloss:0.53242
# [70]	train-mlogloss:0.51888	test-mlogloss:0.530308
# [71]	train-mlogloss:0.516576	test-mlogloss:0.52809
# [72]	train-mlogloss:0.514302	test-mlogloss:0.525957
# [73]	train-mlogloss:0.512474	test-mlogloss:0.524224
# [74]	train-mlogloss:0.510482	test-mlogloss:0.522326
# [75]	train-mlogloss:0.508626	test-mlogloss:0.520593
# [76]	train-mlogloss:0.507072	test-mlogloss:0.519159
# [77]	train-mlogloss:0.505033	test-mlogloss:0.517191
# [78]	train-mlogloss:0.503314	test-mlogloss:0.515566
# [79]	train-mlogloss:0.501357	test-mlogloss:0.513715
# [80]	train-mlogloss:0.499539	test-mlogloss:0.511979
# [81]	train-mlogloss:0.497873	test-mlogloss:0.510403
# [82]	train-mlogloss:0.496125	test-mlogloss:0.508778
# [83]	train-mlogloss:0.494342	test-mlogloss:0.507053
# [84]	train-mlogloss:0.492562	test-mlogloss:0.50537
# [85]	train-mlogloss:0.491033	test-mlogloss:0.503918
# [86]	train-mlogloss:0.489359	test-mlogloss:0.502256
# [87]	train-mlogloss:0.487813	test-mlogloss:0.500779
# [88]	train-mlogloss:0.486326	test-mlogloss:0.499434
# [89]	train-mlogloss:0.484843	test-mlogloss:0.498017
# [90]	train-mlogloss:0.483469	test-mlogloss:0.496759
# [91]	train-mlogloss:0.482056	test-mlogloss:0.49546
# [92]	train-mlogloss:0.480646	test-mlogloss:0.494091
# [93]	train-mlogloss:0.479511	test-mlogloss:0.493114
# [94]	train-mlogloss:0.478465	test-mlogloss:0.49218
# [95]	train-mlogloss:0.477184	test-mlogloss:0.490985
# [96]	train-mlogloss:0.476066	test-mlogloss:0.48999
# [97]	train-mlogloss:0.474822	test-mlogloss:0.488803
# [98]	train-mlogloss:0.473765	test-mlogloss:0.487955
# [99]	train-mlogloss:0.472636	test-mlogloss:0.486959
# [100]	train-mlogloss:0.471432	test-mlogloss:0.485827
# [101]	train-mlogloss:0.470324	test-mlogloss:0.484783
# [102]	train-mlogloss:0.469361	test-mlogloss:0.483943
# [103]	train-mlogloss:0.4684	test-mlogloss:0.48316
# [104]	train-mlogloss:0.467395	test-mlogloss:0.482195
# [105]	train-mlogloss:0.466364	test-mlogloss:0.481256
# [106]	train-mlogloss:0.465567	test-mlogloss:0.480568
# [107]	train-mlogloss:0.46448	test-mlogloss:0.479574
# [108]	train-mlogloss:0.463772	test-mlogloss:0.479015
# [109]	train-mlogloss:0.462779	test-mlogloss:0.478045
# [110]	train-mlogloss:0.461978	test-mlogloss:0.477342
# [111]	train-mlogloss:0.461112	test-mlogloss:0.476598
# [112]	train-mlogloss:0.460294	test-mlogloss:0.475902
# [113]	train-mlogloss:0.459549	test-mlogloss:0.475283
# [114]	train-mlogloss:0.458771	test-mlogloss:0.474586
# [115]	train-mlogloss:0.458189	test-mlogloss:0.474113
# [116]	train-mlogloss:0.457459	test-mlogloss:0.47352
# [117]	train-mlogloss:0.456666	test-mlogloss:0.47281
# [118]	train-mlogloss:0.45586	test-mlogloss:0.472108
# [119]	train-mlogloss:0.455076	test-mlogloss:0.471379
# [120]	train-mlogloss:0.454422	test-mlogloss:0.470848
# [121]	train-mlogloss:0.453695	test-mlogloss:0.470182
# [122]	train-mlogloss:0.452919	test-mlogloss:0.469504
# [123]	train-mlogloss:0.452213	test-mlogloss:0.468881
# [124]	train-mlogloss:0.451535	test-mlogloss:0.46828
# [125]	train-mlogloss:0.450912	test-mlogloss:0.467728
# [126]	train-mlogloss:0.450214	test-mlogloss:0.467121
# [127]	train-mlogloss:0.449571	test-mlogloss:0.466569
# [128]	train-mlogloss:0.448964	test-mlogloss:0.466004
# [129]	train-mlogloss:0.448393	test-mlogloss:0.465531
# [130]	train-mlogloss:0.447822	test-mlogloss:0.465119
# [131]	train-mlogloss:0.447241	test-mlogloss:0.464654
# [132]	train-mlogloss:0.44666	test-mlogloss:0.464196
# [133]	train-mlogloss:0.446104	test-mlogloss:0.463737
# [134]	train-mlogloss:0.445531	test-mlogloss:0.463271
# [135]	train-mlogloss:0.444951	test-mlogloss:0.462732
# [136]	train-mlogloss:0.444369	test-mlogloss:0.462237
# [137]	train-mlogloss:0.443868	test-mlogloss:0.461812
# [138]	train-mlogloss:0.443373	test-mlogloss:0.461407
# [139]	train-mlogloss:0.442887	test-mlogloss:0.461044
# [140]	train-mlogloss:0.442399	test-mlogloss:0.460712
# [141]	train-mlogloss:0.441925	test-mlogloss:0.460355
# [142]	train-mlogloss:0.441467	test-mlogloss:0.45998
# [143]	train-mlogloss:0.440955	test-mlogloss:0.459571
# [144]	train-mlogloss:0.440543	test-mlogloss:0.459246
# [145]	train-mlogloss:0.44009	test-mlogloss:0.458913
# [146]	train-mlogloss:0.439625	test-mlogloss:0.458595
# [147]	train-mlogloss:0.439142	test-mlogloss:0.458217
# [148]	train-mlogloss:0.438691	test-mlogloss:0.457894
# [149]	train-mlogloss:0.438244	test-mlogloss:0.457527
# [150]	train-mlogloss:0.437847	test-mlogloss:0.457242
# [151]	train-mlogloss:0.437471	test-mlogloss:0.456983
# [152]	train-mlogloss:0.437044	test-mlogloss:0.456635
# [153]	train-mlogloss:0.43665	test-mlogloss:0.456383
# [154]	train-mlogloss:0.436247	test-mlogloss:0.456048
# [155]	train-mlogloss:0.435906	test-mlogloss:0.455872
# [156]	train-mlogloss:0.435491	test-mlogloss:0.455541
# [157]	train-mlogloss:0.435124	test-mlogloss:0.455242
# [158]	train-mlogloss:0.43475	test-mlogloss:0.454936
# [159]	train-mlogloss:0.434367	test-mlogloss:0.454674
# [160]	train-mlogloss:0.433983	test-mlogloss:0.454422
# [161]	train-mlogloss:0.433596	test-mlogloss:0.454132
# [162]	train-mlogloss:0.433266	test-mlogloss:0.453852
# [163]	train-mlogloss:0.432902	test-mlogloss:0.453608
# [164]	train-mlogloss:0.432528	test-mlogloss:0.453362
# [165]	train-mlogloss:0.43218	test-mlogloss:0.453093
# [166]	train-mlogloss:0.431809	test-mlogloss:0.452808
# [167]	train-mlogloss:0.431473	test-mlogloss:0.452513
# [168]	train-mlogloss:0.4311	test-mlogloss:0.45221
# [169]	train-mlogloss:0.430776	test-mlogloss:0.45193
# [170]	train-mlogloss:0.430485	test-mlogloss:0.451731
# [171]	train-mlogloss:0.430172	test-mlogloss:0.451512
# [172]	train-mlogloss:0.429848	test-mlogloss:0.45125
# [173]	train-mlogloss:0.429534	test-mlogloss:0.451041
# [174]	train-mlogloss:0.429176	test-mlogloss:0.450803
# [175]	train-mlogloss:0.428881	test-mlogloss:0.450622
# [176]	train-mlogloss:0.4286	test-mlogloss:0.450439
# [177]	train-mlogloss:0.428287	test-mlogloss:0.450223
# [178]	train-mlogloss:0.427951	test-mlogloss:0.449977
# [179]	train-mlogloss:0.427635	test-mlogloss:0.449747
# [180]	train-mlogloss:0.427316	test-mlogloss:0.449571
# [181]	train-mlogloss:0.427029	test-mlogloss:0.449361
# [182]	train-mlogloss:0.42677	test-mlogloss:0.449168
# [183]	train-mlogloss:0.42648	test-mlogloss:0.448998
# [184]	train-mlogloss:0.426201	test-mlogloss:0.44881
# [185]	train-mlogloss:0.425923	test-mlogloss:0.44866
# [186]	train-mlogloss:0.425592	test-mlogloss:0.448462
# [187]	train-mlogloss:0.425307	test-mlogloss:0.448275
# [188]	train-mlogloss:0.425035	test-mlogloss:0.448078
# [189]	train-mlogloss:0.424781	test-mlogloss:0.447919
# [190]	train-mlogloss:0.424523	test-mlogloss:0.447778
# [191]	train-mlogloss:0.424259	test-mlogloss:0.447683
# [192]	train-mlogloss:0.423917	test-mlogloss:0.447499
# [193]	train-mlogloss:0.42365	test-mlogloss:0.447352
# [194]	train-mlogloss:0.423423	test-mlogloss:0.447212
# [195]	train-mlogloss:0.423175	test-mlogloss:0.447074
# [196]	train-mlogloss:0.422884	test-mlogloss:0.446936
# [197]	train-mlogloss:0.422625	test-mlogloss:0.446822
# [198]	train-mlogloss:0.422407	test-mlogloss:0.446695
# [199]	train-mlogloss:0.42216	test-mlogloss:0.446566
# [200]	train-mlogloss:0.42188	test-mlogloss:0.446414
# [201]	train-mlogloss:0.421618	test-mlogloss:0.446255
# [202]	train-mlogloss:0.421362	test-mlogloss:0.446169
# [203]	train-mlogloss:0.421115	test-mlogloss:0.446081
# [204]	train-mlogloss:0.42084	test-mlogloss:0.445902
# [205]	train-mlogloss:0.420597	test-mlogloss:0.445834
# [206]	train-mlogloss:0.420379	test-mlogloss:0.445726
# [207]	train-mlogloss:0.420177	test-mlogloss:0.445605
# [208]	train-mlogloss:0.420005	test-mlogloss:0.445464
# [209]	train-mlogloss:0.419746	test-mlogloss:0.445329
# [210]	train-mlogloss:0.41947	test-mlogloss:0.445179
# [211]	train-mlogloss:0.419278	test-mlogloss:0.445052
# [212]	train-mlogloss:0.419043	test-mlogloss:0.444911
# [213]	train-mlogloss:0.418841	test-mlogloss:0.444783
# [214]	train-mlogloss:0.418578	test-mlogloss:0.44465
# [215]	train-mlogloss:0.41838	test-mlogloss:0.444533
# [216]	train-mlogloss:0.418173	test-mlogloss:0.444391
# [217]	train-mlogloss:0.417946	test-mlogloss:0.444283
# [218]	train-mlogloss:0.417663	test-mlogloss:0.444112
# [219]	train-mlogloss:0.417402	test-mlogloss:0.444013
# [220]	train-mlogloss:0.417256	test-mlogloss:0.443878
# [221]	train-mlogloss:0.417069	test-mlogloss:0.443759
# [222]	train-mlogloss:0.416856	test-mlogloss:0.443664
# [223]	train-mlogloss:0.416621	test-mlogloss:0.443492
# [224]	train-mlogloss:0.416394	test-mlogloss:0.443358
# [225]	train-mlogloss:0.416193	test-mlogloss:0.443205
# [226]	train-mlogloss:0.415983	test-mlogloss:0.443068
# [227]	train-mlogloss:0.415733	test-mlogloss:0.443034
# [228]	train-mlogloss:0.415481	test-mlogloss:0.44304
# [229]	train-mlogloss:0.415294	test-mlogloss:0.442994
# [230]	train-mlogloss:0.415033	test-mlogloss:0.442846
# [231]	train-mlogloss:0.414828	test-mlogloss:0.442714
# [232]	train-mlogloss:0.414606	test-mlogloss:0.4426
# [233]	train-mlogloss:0.414413	test-mlogloss:0.442559
# [234]	train-mlogloss:0.414213	test-mlogloss:0.442481
# [235]	train-mlogloss:0.414048	test-mlogloss:0.442374
# [236]	train-mlogloss:0.413831	test-mlogloss:0.44228
# [237]	train-mlogloss:0.413609	test-mlogloss:0.442181
# [238]	train-mlogloss:0.413449	test-mlogloss:0.442092
# [239]	train-mlogloss:0.413234	test-mlogloss:0.44198
# [240]	train-mlogloss:0.413024	test-mlogloss:0.441883
# [241]	train-mlogloss:0.412855	test-mlogloss:0.441829
# [242]	train-mlogloss:0.412619	test-mlogloss:0.441767
# [243]	train-mlogloss:0.412428	test-mlogloss:0.441676
# [244]	train-mlogloss:0.412256	test-mlogloss:0.44162
# [245]	train-mlogloss:0.412036	test-mlogloss:0.441546
# [246]	train-mlogloss:0.411862	test-mlogloss:0.441488
# [247]	train-mlogloss:0.411673	test-mlogloss:0.441399
# [248]	train-mlogloss:0.41145	test-mlogloss:0.44131
# [249]	train-mlogloss:0.411299	test-mlogloss:0.441265
# [250]	train-mlogloss:0.411061	test-mlogloss:0.441182
# [251]	train-mlogloss:0.410879	test-mlogloss:0.441123
# [252]	train-mlogloss:0.410628	test-mlogloss:0.441014
# [253]	train-mlogloss:0.410411	test-mlogloss:0.44097
# [254]	train-mlogloss:0.410229	test-mlogloss:0.44091
# [255]	train-mlogloss:0.41008	test-mlogloss:0.440848
# [256]	train-mlogloss:0.409883	test-mlogloss:0.44076
# [257]	train-mlogloss:0.409643	test-mlogloss:0.440653
# [258]	train-mlogloss:0.40941	test-mlogloss:0.440554
# [259]	train-mlogloss:0.409222	test-mlogloss:0.440511
# [260]	train-mlogloss:0.409037	test-mlogloss:0.440432
# [261]	train-mlogloss:0.408864	test-mlogloss:0.440336
# [262]	train-mlogloss:0.408648	test-mlogloss:0.440303
# [263]	train-mlogloss:0.408406	test-mlogloss:0.440227
# [264]	train-mlogloss:0.408226	test-mlogloss:0.44021
# [265]	train-mlogloss:0.408021	test-mlogloss:0.440146
# [266]	train-mlogloss:0.407787	test-mlogloss:0.440043
# [267]	train-mlogloss:0.407584	test-mlogloss:0.439995
# [268]	train-mlogloss:0.407376	test-mlogloss:0.439879
# [269]	train-mlogloss:0.407235	test-mlogloss:0.43985
# [270]	train-mlogloss:0.407021	test-mlogloss:0.439801
# [271]	train-mlogloss:0.406871	test-mlogloss:0.43977
# [272]	train-mlogloss:0.406698	test-mlogloss:0.439741
# [273]	train-mlogloss:0.406546	test-mlogloss:0.439729
# [274]	train-mlogloss:0.40632	test-mlogloss:0.439656
# [275]	train-mlogloss:0.406108	test-mlogloss:0.43958
# [276]	train-mlogloss:0.405857	test-mlogloss:0.439527
# [277]	train-mlogloss:0.405635	test-mlogloss:0.439461
# [278]	train-mlogloss:0.40543	test-mlogloss:0.439438
# [279]	train-mlogloss:0.405198	test-mlogloss:0.439372
# [280]	train-mlogloss:0.404922	test-mlogloss:0.43928
# [281]	train-mlogloss:0.404688	test-mlogloss:0.439187
# [282]	train-mlogloss:0.404492	test-mlogloss:0.439165
# [283]	train-mlogloss:0.404334	test-mlogloss:0.439114
# [284]	train-mlogloss:0.40409	test-mlogloss:0.439022
# [285]	train-mlogloss:0.403874	test-mlogloss:0.439005
# [286]	train-mlogloss:0.403708	test-mlogloss:0.438935
# [287]	train-mlogloss:0.403493	test-mlogloss:0.43891
# [288]	train-mlogloss:0.403309	test-mlogloss:0.438867
# [289]	train-mlogloss:0.403103	test-mlogloss:0.438814
# [290]	train-mlogloss:0.402927	test-mlogloss:0.438795
# [291]	train-mlogloss:0.40271	test-mlogloss:0.438743
# [292]	train-mlogloss:0.402496	test-mlogloss:0.438659
# [293]	train-mlogloss:0.402305	test-mlogloss:0.438614
# [294]	train-mlogloss:0.402091	test-mlogloss:0.438593
# [295]	train-mlogloss:0.401952	test-mlogloss:0.43857
# [296]	train-mlogloss:0.401791	test-mlogloss:0.438505
# [297]	train-mlogloss:0.401639	test-mlogloss:0.43843
# [298]	train-mlogloss:0.401497	test-mlogloss:0.438413
# [299]	train-mlogloss:0.40138	test-mlogloss:0.438385
# [300]	train-mlogloss:0.401214	test-mlogloss:0.438335
# [301]	train-mlogloss:0.401032	test-mlogloss:0.438296
# [302]	train-mlogloss:0.400807	test-mlogloss:0.438247
# [303]	train-mlogloss:0.400619	test-mlogloss:0.438171
# [304]	train-mlogloss:0.40045	test-mlogloss:0.43813
# [305]	train-mlogloss:0.400213	test-mlogloss:0.438058
# [306]	train-mlogloss:0.400075	test-mlogloss:0.43802
# [307]	train-mlogloss:0.399878	test-mlogloss:0.437962
# [308]	train-mlogloss:0.39971	test-mlogloss:0.437924
# [309]	train-mlogloss:0.39951	test-mlogloss:0.43784
# [310]	train-mlogloss:0.399299	test-mlogloss:0.43781
# [311]	train-mlogloss:0.399104	test-mlogloss:0.437809
# [312]	train-mlogloss:0.398907	test-mlogloss:0.437787
# [313]	train-mlogloss:0.398786	test-mlogloss:0.437749
# [314]	train-mlogloss:0.39864	test-mlogloss:0.437683
# [315]	train-mlogloss:0.398425	test-mlogloss:0.437638
# [316]	train-mlogloss:0.398214	test-mlogloss:0.437576
# [317]	train-mlogloss:0.398045	test-mlogloss:0.437531
# [318]	train-mlogloss:0.397885	test-mlogloss:0.43748
# [319]	train-mlogloss:0.397727	test-mlogloss:0.437423
# [320]	train-mlogloss:0.397535	test-mlogloss:0.437366
# [321]	train-mlogloss:0.397353	test-mlogloss:0.437349
# [322]	train-mlogloss:0.397141	test-mlogloss:0.437308
# [323]	train-mlogloss:0.39689	test-mlogloss:0.43727
# [324]	train-mlogloss:0.3967	test-mlogloss:0.437223
# [325]	train-mlogloss:0.396462	test-mlogloss:0.43716
# [326]	train-mlogloss:0.396338	test-mlogloss:0.437129
# [327]	train-mlogloss:0.396154	test-mlogloss:0.437084
# [328]	train-mlogloss:0.396005	test-mlogloss:0.437067
# [329]	train-mlogloss:0.395797	test-mlogloss:0.437036
# [330]	train-mlogloss:0.395601	test-mlogloss:0.436993
# [331]	train-mlogloss:0.395444	test-mlogloss:0.43695
# [332]	train-mlogloss:0.395304	test-mlogloss:0.436896
# [333]	train-mlogloss:0.395162	test-mlogloss:0.436878
# [334]	train-mlogloss:0.39505	test-mlogloss:0.436834
# [335]	train-mlogloss:0.394893	test-mlogloss:0.436783
# [336]	train-mlogloss:0.394757	test-mlogloss:0.436721
# [337]	train-mlogloss:0.394617	test-mlogloss:0.436693
# [338]	train-mlogloss:0.394461	test-mlogloss:0.436649
# [339]	train-mlogloss:0.394229	test-mlogloss:0.436578
# [340]	train-mlogloss:0.394065	test-mlogloss:0.436542
# [341]	train-mlogloss:0.393849	test-mlogloss:0.436502
# [342]	train-mlogloss:0.39361	test-mlogloss:0.436453
# [343]	train-mlogloss:0.39344	test-mlogloss:0.436404
# [344]	train-mlogloss:0.393298	test-mlogloss:0.436354
# [345]	train-mlogloss:0.393127	test-mlogloss:0.43632
# [346]	train-mlogloss:0.392935	test-mlogloss:0.436283
# [347]	train-mlogloss:0.392769	test-mlogloss:0.436256
# [348]	train-mlogloss:0.392638	test-mlogloss:0.436226
# [349]	train-mlogloss:0.392468	test-mlogloss:0.436205
# [350]	train-mlogloss:0.392353	test-mlogloss:0.43618
# [351]	train-mlogloss:0.392217	test-mlogloss:0.436145
# [352]	train-mlogloss:0.392064	test-mlogloss:0.436125
# [353]	train-mlogloss:0.391894	test-mlogloss:0.436095
# [354]	train-mlogloss:0.391738	test-mlogloss:0.436063
# [355]	train-mlogloss:0.391583	test-mlogloss:0.436035
# [356]	train-mlogloss:0.39139	test-mlogloss:0.435986
# [357]	train-mlogloss:0.391235	test-mlogloss:0.435971
# [358]	train-mlogloss:0.391068	test-mlogloss:0.435971
# [359]	train-mlogloss:0.390903	test-mlogloss:0.435916
# [360]	train-mlogloss:0.390722	test-mlogloss:0.435926
# [361]	train-mlogloss:0.390513	test-mlogloss:0.435887
# [362]	train-mlogloss:0.390344	test-mlogloss:0.435886
# [363]	train-mlogloss:0.390184	test-mlogloss:0.435826
# [364]	train-mlogloss:0.39002	test-mlogloss:0.435808
# [365]	train-mlogloss:0.389801	test-mlogloss:0.435722
# [366]	train-mlogloss:0.389635	test-mlogloss:0.43568
# [367]	train-mlogloss:0.389484	test-mlogloss:0.435709
# [368]	train-mlogloss:0.389315	test-mlogloss:0.435706
# [369]	train-mlogloss:0.389165	test-mlogloss:0.435716
# [370]	train-mlogloss:0.389025	test-mlogloss:0.435692
# [371]	train-mlogloss:0.388871	test-mlogloss:0.435594
# [372]	train-mlogloss:0.38874	test-mlogloss:0.435568
# [373]	train-mlogloss:0.388605	test-mlogloss:0.435535
# [374]	train-mlogloss:0.388475	test-mlogloss:0.435505
# [375]	train-mlogloss:0.388372	test-mlogloss:0.435482
# [376]	train-mlogloss:0.388196	test-mlogloss:0.435452
# [377]	train-mlogloss:0.387975	test-mlogloss:0.435409
# [378]	train-mlogloss:0.387748	test-mlogloss:0.435354
# [379]	train-mlogloss:0.387613	test-mlogloss:0.435331
# [380]	train-mlogloss:0.387463	test-mlogloss:0.435265
# [381]	train-mlogloss:0.3873	test-mlogloss:0.435188
# [382]	train-mlogloss:0.38718	test-mlogloss:0.435176
# [383]	train-mlogloss:0.387062	test-mlogloss:0.435162
# [384]	train-mlogloss:0.386856	test-mlogloss:0.43515
# [385]	train-mlogloss:0.386697	test-mlogloss:0.435139
# [386]	train-mlogloss:0.386553	test-mlogloss:0.435158
# [387]	train-mlogloss:0.386413	test-mlogloss:0.435207
# [388]	train-mlogloss:0.386254	test-mlogloss:0.435211
# [389]	train-mlogloss:0.386096	test-mlogloss:0.435205
# [390]	train-mlogloss:0.385911	test-mlogloss:0.435234
# [391]	train-mlogloss:0.385733	test-mlogloss:0.435165
# [392]	train-mlogloss:0.385568	test-mlogloss:0.435141
# [393]	train-mlogloss:0.385458	test-mlogloss:0.435127
# [394]	train-mlogloss:0.38529	test-mlogloss:0.435154
# [395]	train-mlogloss:0.385164	test-mlogloss:0.435139
# [396]	train-mlogloss:0.385017	test-mlogloss:0.435074
# [397]	train-mlogloss:0.384838	test-mlogloss:0.435057
# [398]	train-mlogloss:0.384651	test-mlogloss:0.435041
# [399]	train-mlogloss:0.38449	test-mlogloss:0.435027
# [400]	train-mlogloss:0.384345	test-mlogloss:0.434998
# [401]	train-mlogloss:0.384209	test-mlogloss:0.43497
# [402]	train-mlogloss:0.384037	test-mlogloss:0.434941
# [403]	train-mlogloss:0.383913	test-mlogloss:0.434919
# [404]	train-mlogloss:0.383748	test-mlogloss:0.434908
# [405]	train-mlogloss:0.383594	test-mlogloss:0.4349
# [406]	train-mlogloss:0.383429	test-mlogloss:0.434917
# [407]	train-mlogloss:0.3833	test-mlogloss:0.434891
# [408]	train-mlogloss:0.3831	test-mlogloss:0.434854
# [409]	train-mlogloss:0.382929	test-mlogloss:0.43481
# [410]	train-mlogloss:0.382761	test-mlogloss:0.434799
# [411]	train-mlogloss:0.382608	test-mlogloss:0.434767
# [412]	train-mlogloss:0.382458	test-mlogloss:0.434751
# [413]	train-mlogloss:0.382376	test-mlogloss:0.434711
# [414]	train-mlogloss:0.382253	test-mlogloss:0.43469
# [415]	train-mlogloss:0.382094	test-mlogloss:0.434691
# [416]	train-mlogloss:0.381995	test-mlogloss:0.434682
# [417]	train-mlogloss:0.381865	test-mlogloss:0.434673
# [418]	train-mlogloss:0.381741	test-mlogloss:0.434648
# [419]	train-mlogloss:0.381611	test-mlogloss:0.434639
# [420]	train-mlogloss:0.381459	test-mlogloss:0.434622
# [421]	train-mlogloss:0.381332	test-mlogloss:0.434624
# [422]	train-mlogloss:0.381221	test-mlogloss:0.434605
# [423]	train-mlogloss:0.381065	test-mlogloss:0.434573
# [424]	train-mlogloss:0.380944	test-mlogloss:0.434553
# [425]	train-mlogloss:0.380775	test-mlogloss:0.43451
# [426]	train-mlogloss:0.380602	test-mlogloss:0.434458
# [427]	train-mlogloss:0.380475	test-mlogloss:0.434473
# [428]	train-mlogloss:0.380335	test-mlogloss:0.434489
# [429]	train-mlogloss:0.380168	test-mlogloss:0.434437
# [430]	train-mlogloss:0.380053	test-mlogloss:0.434448
# [431]	train-mlogloss:0.379929	test-mlogloss:0.434466
# [432]	train-mlogloss:0.379785	test-mlogloss:0.43446
# [433]	train-mlogloss:0.379627	test-mlogloss:0.434418
# [434]	train-mlogloss:0.379496	test-mlogloss:0.434404
# [435]	train-mlogloss:0.379343	test-mlogloss:0.43442
# [436]	train-mlogloss:0.379178	test-mlogloss:0.434403
# [437]	train-mlogloss:0.379035	test-mlogloss:0.434408
# [438]	train-mlogloss:0.378876	test-mlogloss:0.434409
# [439]	train-mlogloss:0.378694	test-mlogloss:0.434418
# [440]	train-mlogloss:0.378563	test-mlogloss:0.434393
# [441]	train-mlogloss:0.378359	test-mlogloss:0.434321
# [442]	train-mlogloss:0.378232	test-mlogloss:0.434287
# [443]	train-mlogloss:0.3781	test-mlogloss:0.434292
# [444]	train-mlogloss:0.377955	test-mlogloss:0.434279
# [445]	train-mlogloss:0.377804	test-mlogloss:0.434264
# [446]	train-mlogloss:0.377692	test-mlogloss:0.434278
# [447]	train-mlogloss:0.377587	test-mlogloss:0.434269
# [448]	train-mlogloss:0.37747	test-mlogloss:0.434237
# [449]	train-mlogloss:0.377345	test-mlogloss:0.434263
# [450]	train-mlogloss:0.377195	test-mlogloss:0.434243
# [451]	train-mlogloss:0.377052	test-mlogloss:0.434239
# [452]	train-mlogloss:0.376926	test-mlogloss:0.434252
# [453]	train-mlogloss:0.376803	test-mlogloss:0.434226
# [454]	train-mlogloss:0.376683	test-mlogloss:0.434245
# [455]	train-mlogloss:0.376513	test-mlogloss:0.434235
# [456]	train-mlogloss:0.376383	test-mlogloss:0.434198
# [457]	train-mlogloss:0.376283	test-mlogloss:0.434154
# [458]	train-mlogloss:0.376196	test-mlogloss:0.43414
# [459]	train-mlogloss:0.376085	test-mlogloss:0.434142
# [460]	train-mlogloss:0.375966	test-mlogloss:0.434126
# [461]	train-mlogloss:0.375858	test-mlogloss:0.434132
# [462]	train-mlogloss:0.375728	test-mlogloss:0.43414
# [463]	train-mlogloss:0.375623	test-mlogloss:0.434125
# [464]	train-mlogloss:0.375466	test-mlogloss:0.434096
# [465]	train-mlogloss:0.375285	test-mlogloss:0.434055
# [466]	train-mlogloss:0.375167	test-mlogloss:0.434037
# [467]	train-mlogloss:0.375069	test-mlogloss:0.434041
# [468]	train-mlogloss:0.374926	test-mlogloss:0.433955
# [469]	train-mlogloss:0.374773	test-mlogloss:0.433906
# [470]	train-mlogloss:0.374589	test-mlogloss:0.433859
# [471]	train-mlogloss:0.374456	test-mlogloss:0.433864
# [472]	train-mlogloss:0.374304	test-mlogloss:0.433867
# [473]	train-mlogloss:0.374163	test-mlogloss:0.433874
# [474]	train-mlogloss:0.374054	test-mlogloss:0.433828
# [475]	train-mlogloss:0.373897	test-mlogloss:0.433835
# [476]	train-mlogloss:0.373757	test-mlogloss:0.433832
# [477]	train-mlogloss:0.373605	test-mlogloss:0.433874
# [478]	train-mlogloss:0.373424	test-mlogloss:0.433892
# [479]	train-mlogloss:0.373326	test-mlogloss:0.433894
# [480]	train-mlogloss:0.373207	test-mlogloss:0.433891
# [481]	train-mlogloss:0.373046	test-mlogloss:0.433855
# [482]	train-mlogloss:0.372878	test-mlogloss:0.433851
# [483]	train-mlogloss:0.372706	test-mlogloss:0.433822
# [484]	train-mlogloss:0.37255	test-mlogloss:0.433766
# [485]	train-mlogloss:0.37243	test-mlogloss:0.433756
# [486]	train-mlogloss:0.372303	test-mlogloss:0.43372
# [487]	train-mlogloss:0.372189	test-mlogloss:0.433747
# [488]	train-mlogloss:0.372087	test-mlogloss:0.433738
# [489]	train-mlogloss:0.371958	test-mlogloss:0.43373
# [490]	train-mlogloss:0.371834	test-mlogloss:0.433729
# [491]	train-mlogloss:0.371709	test-mlogloss:0.43371
# [492]	train-mlogloss:0.371586	test-mlogloss:0.433698
# [493]	train-mlogloss:0.371456	test-mlogloss:0.433671
# [494]	train-mlogloss:0.371295	test-mlogloss:0.433695
# [495]	train-mlogloss:0.371171	test-mlogloss:0.433697
# [496]	train-mlogloss:0.371049	test-mlogloss:0.433691
# [497]	train-mlogloss:0.370906	test-mlogloss:0.433709
# [498]	train-mlogloss:0.370788	test-mlogloss:0.433716
# [499]	train-mlogloss:0.370674	test-mlogloss:0.433711
# [500]	train-mlogloss:0.370575	test-mlogloss:0.433697
# [501]	train-mlogloss:0.370447	test-mlogloss:0.433677
# [502]	train-mlogloss:0.3703	test-mlogloss:0.433669
# [503]	train-mlogloss:0.370178	test-mlogloss:0.433669
# [504]	train-mlogloss:0.370007	test-mlogloss:0.433677
# [505]	train-mlogloss:0.369839	test-mlogloss:0.433648
# [506]	train-mlogloss:0.36975	test-mlogloss:0.433642
# [507]	train-mlogloss:0.369652	test-mlogloss:0.433651
# [508]	train-mlogloss:0.369468	test-mlogloss:0.433649
# [509]	train-mlogloss:0.369343	test-mlogloss:0.433615
# [510]	train-mlogloss:0.369273	test-mlogloss:0.433627
# [511]	train-mlogloss:0.369156	test-mlogloss:0.433633
# [512]	train-mlogloss:0.369054	test-mlogloss:0.433632
# [513]	train-mlogloss:0.368914	test-mlogloss:0.433633
# [514]	train-mlogloss:0.368831	test-mlogloss:0.433641
# [515]	train-mlogloss:0.3687	test-mlogloss:0.433617
# [516]	train-mlogloss:0.36856	test-mlogloss:0.433649
# [517]	train-mlogloss:0.368433	test-mlogloss:0.433642
# [518]	train-mlogloss:0.36834	test-mlogloss:0.433631
# [519]	train-mlogloss:0.368209	test-mlogloss:0.433611
# [520]	train-mlogloss:0.368062	test-mlogloss:0.433604
# [521]	train-mlogloss:0.367959	test-mlogloss:0.433594
# [522]	train-mlogloss:0.367815	test-mlogloss:0.433558
# [523]	train-mlogloss:0.367661	test-mlogloss:0.433528
# [524]	train-mlogloss:0.367518	test-mlogloss:0.433455
# [525]	train-mlogloss:0.367393	test-mlogloss:0.433425
# [526]	train-mlogloss:0.367255	test-mlogloss:0.433414
# [527]	train-mlogloss:0.367113	test-mlogloss:0.433412
# [528]	train-mlogloss:0.366954	test-mlogloss:0.433435
# [529]	train-mlogloss:0.366848	test-mlogloss:0.433415
# [530]	train-mlogloss:0.366728	test-mlogloss:0.433403
# [531]	train-mlogloss:0.366586	test-mlogloss:0.433407
# [532]	train-mlogloss:0.366494	test-mlogloss:0.433381
# [533]	train-mlogloss:0.366375	test-mlogloss:0.433371
# [534]	train-mlogloss:0.366279	test-mlogloss:0.433354
# [535]	train-mlogloss:0.366183	test-mlogloss:0.433306
# [536]	train-mlogloss:0.366061	test-mlogloss:0.433289
# [537]	train-mlogloss:0.36593	test-mlogloss:0.43329
# [538]	train-mlogloss:0.365799	test-mlogloss:0.433257
# [539]	train-mlogloss:0.365666	test-mlogloss:0.433249
# [540]	train-mlogloss:0.365541	test-mlogloss:0.433258
# [541]	train-mlogloss:0.365391	test-mlogloss:0.433246
# [542]	train-mlogloss:0.36526	test-mlogloss:0.433224
# [543]	train-mlogloss:0.365133	test-mlogloss:0.43323
# [544]	train-mlogloss:0.364993	test-mlogloss:0.433205
# [545]	train-mlogloss:0.364847	test-mlogloss:0.433208
# [546]	train-mlogloss:0.364701	test-mlogloss:0.433212
# [547]	train-mlogloss:0.364611	test-mlogloss:0.433207
# [548]	train-mlogloss:0.364498	test-mlogloss:0.433194
# [549]	train-mlogloss:0.364411	test-mlogloss:0.43317
# [550]	train-mlogloss:0.364291	test-mlogloss:0.433142
# [551]	train-mlogloss:0.364182	test-mlogloss:0.433146
# [552]	train-mlogloss:0.364084	test-mlogloss:0.433133
# [553]	train-mlogloss:0.363969	test-mlogloss:0.433125
# [554]	train-mlogloss:0.363847	test-mlogloss:0.433134
# [555]	train-mlogloss:0.363708	test-mlogloss:0.433112
# [556]	train-mlogloss:0.363588	test-mlogloss:0.433162
# [557]	train-mlogloss:0.363426	test-mlogloss:0.433173
# [558]	train-mlogloss:0.363279	test-mlogloss:0.433157
# [559]	train-mlogloss:0.363164	test-mlogloss:0.433151
# [560]	train-mlogloss:0.363048	test-mlogloss:0.433159
# [561]	train-mlogloss:0.36288	test-mlogloss:0.433182
# [562]	train-mlogloss:0.362772	test-mlogloss:0.433178
# [563]	train-mlogloss:0.362659	test-mlogloss:0.433192
# [564]	train-mlogloss:0.36253	test-mlogloss:0.433199
# [565]	train-mlogloss:0.362424	test-mlogloss:0.433225
# [566]	train-mlogloss:0.362269	test-mlogloss:0.433182
# [567]	train-mlogloss:0.362138	test-mlogloss:0.433158
# [568]	train-mlogloss:0.362018	test-mlogloss:0.433145
# [569]	train-mlogloss:0.361879	test-mlogloss:0.433094
# [570]	train-mlogloss:0.361736	test-mlogloss:0.433043
# [571]	train-mlogloss:0.361619	test-mlogloss:0.433063
# [572]	train-mlogloss:0.361518	test-mlogloss:0.433057
# [573]	train-mlogloss:0.361427	test-mlogloss:0.433043
# [574]	train-mlogloss:0.361308	test-mlogloss:0.433006
# [575]	train-mlogloss:0.361197	test-mlogloss:0.433014
# [576]	train-mlogloss:0.361072	test-mlogloss:0.43302
# [577]	train-mlogloss:0.360945	test-mlogloss:0.433033
# [578]	train-mlogloss:0.360809	test-mlogloss:0.433053
# [579]	train-mlogloss:0.360695	test-mlogloss:0.433021
# [580]	train-mlogloss:0.360575	test-mlogloss:0.433031
# [581]	train-mlogloss:0.360442	test-mlogloss:0.433028
# [582]	train-mlogloss:0.36032	test-mlogloss:0.433019
# [583]	train-mlogloss:0.360206	test-mlogloss:0.43302
# [584]	train-mlogloss:0.360047	test-mlogloss:0.432983
# [585]	train-mlogloss:0.359922	test-mlogloss:0.432992
# [586]	train-mlogloss:0.359818	test-mlogloss:0.433018
# [587]	train-mlogloss:0.359692	test-mlogloss:0.432993
# [588]	train-mlogloss:0.359581	test-mlogloss:0.433
# [589]	train-mlogloss:0.35947	test-mlogloss:0.432989
# [590]	train-mlogloss:0.359348	test-mlogloss:0.432997
# [591]	train-mlogloss:0.359229	test-mlogloss:0.433003
# [592]	train-mlogloss:0.359134	test-mlogloss:0.432998
# [593]	train-mlogloss:0.358972	test-mlogloss:0.433009
# [594]	train-mlogloss:0.358866	test-mlogloss:0.433025
# [595]	train-mlogloss:0.358712	test-mlogloss:0.433013
# [596]	train-mlogloss:0.358576	test-mlogloss:0.43303
# [597]	train-mlogloss:0.358455	test-mlogloss:0.433038
# [598]	train-mlogloss:0.358303	test-mlogloss:0.43305
# [599]	train-mlogloss:0.358147	test-mlogloss:0.433076
# [600]	train-mlogloss:0.35804	test-mlogloss:0.433078
# [601]	train-mlogloss:0.357929	test-mlogloss:0.433056
# [602]	train-mlogloss:0.357836	test-mlogloss:0.433037
# [603]	train-mlogloss:0.357728	test-mlogloss:0.433034
# [604]	train-mlogloss:0.357596	test-mlogloss:0.433049
# Stopping. Best iteration:
# [584]	train-mlogloss:0.360047	test-mlogloss:0.432983

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1300)
print(preds[0:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3cdb66c2dccd> in <module>()
# ----> 1 preds, model = runXGB(train_X, train_y, test_X, num_rounds=1300)
#       2 print(preds[0:5])
#
# NameError: name 'runXGB' is not defined

# %%
# print(preds[0:5])
# test_df['listing_id'].head()
# Out:
# 10000      5529
# 100013    14597
# 100016    43396
# 100020    25538
# 100099    26644
# Name: listing_id, dtype: int64

# %%
def pred_to_csv(model_name, y_test, time):
    y_pred = pd.DataFrame()
    y_pred['listing_id'] = test_df['listing_id']
    for i in range(len(list(y_test))):
        [y_pred.loc[y_pred.index[i], 'high'], y_pred.loc[y_pred.index[i], 'low'], y_pred.loc[y_pred.index[i], 'medium']] = list(y_test[i])

    print(y_pred.head())

    y_pred.to_csv("results/pred_"+ model_name + str(time) + ".csv", index=False)

    print("\n\nDone! CSV for "+model_name+"'s predictions created!\n")

# %%
pred_to_csv("xgboost", preds, 22)
# Out:
#         listing_id      high       low    medium
# 10000         5529  0.000134  0.003511  0.996356
# 100013       14597  0.000187  0.000305  0.999508
# 100016       43396  0.000014  0.000038  0.999948
# 100020       25538  0.006909  0.185572  0.807519
# 100099       26644  0.000559  0.059903  0.939538
#
#
# Done! CSV for xgboost's predictions created!

# %%
model = RandomForestClassifier()
print(model.get_params())

grid = {'n_estimators' : [200, 350, 500, 750, 1000],
        'max_depth': [int(x) for x in np.linspace(10, 110, 11)],
        'min_samples_split': [2, 5, 10, 25, 50],
        'min_samples_leaf': [2, 5, 10, 25, 50],
        }
#'max_feaures': ['sqrt', 'log2']
#'bootstrap': [True, False]

kFold = StratifiedKFold(n_splits=3, shuffle=True, random_state=7)
randomSearch = RandomizedSearchCV(estimator=model, param_distributions=grid, n_iter=50, 
                                  verbose=2, scoring="neg_log_loss", n_jobs=-1, cv=kFold)

rs_result = randomSearch.fit(train_X, train_y)

print("Best: %f using %s" % (rs_result.best_score_, rs_result.best_params_))
means = rs_result.cv_results_['mean_test_score']
stds = rs_result.cv_results_['std_test_score']
params = rs_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# {'bootstrap': True, 'random_state': None, 'verbose': 0, 'n_estimators': 10, 'warm_start': False, 'max_features': 'auto', 'n_jobs': 1, 'min_impurity_split': None, 'min_samples_leaf': 1, 'max_depth': None, 'min_samples_split': 2, 'class_weight': None, 'min_weight_fraction_leaf': 0.0, 'max_leaf_nodes': None, 'criterion': 'gini', 'oob_score': False, 'min_impurity_decrease': 0.0}
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110, total= 2.4min
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110, total= 2.4min
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=2, max_depth=110, total= 2.4min
# [CV] min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100, total= 4.4min
# [CV] min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100, total= 4.0min
# [CV] min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=350, min_samples_split=50, max_depth=100, total= 4.0min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100, total=16.2min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100, total=15.5min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=5, max_depth=100, total=15.5min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40, total= 3.7min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40, total= 3.7min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=10, max_depth=40, total= 3.7min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60, total= 3.7min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90, total=11.5min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60, total= 3.9min
# [CV] min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90, total=11.5min
# [CV] min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=50, max_depth=90, total=11.5min
# [CV] min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=60, total= 3.8min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30, total= 7.4min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=10, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30, total= 7.4min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60, total= 1.4min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30
# [CV]  min_samples_leaf=5, n_estimators=500, min_samples_split=5, max_depth=30, total= 7.3min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60, total= 1.4min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=25, max_depth=60, total= 1.4min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30, total= 5.4min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30, total= 5.4min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=30, total= 5.3min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70, total= 5.2min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70, total= 5.2min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=25, max_depth=70, total= 5.2min
# [CV] min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 50.7min
# [CV]  min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60
# [CV]  min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60
# [CV]  min_samples_leaf=25, n_estimators=200, min_samples_split=50, max_depth=60, total= 1.3min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60, total= 5.5min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50, total=15.9min
# [CV] min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50, total=15.8min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60, total= 5.5min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=5, max_depth=50, total=15.6min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=10, n_estimators=500, min_samples_split=10, max_depth=60, total= 5.6min
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20, total=10.9min
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100, total=18.8min
# [CV] min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100, total=18.7min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=10, max_depth=100, total=18.7min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20, total=10.8min
# [CV] min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=5, n_estimators=1000, min_samples_split=10, max_depth=20, total=10.6min
# [CV] min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70, total= 1.9min
# [CV] min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70, total= 1.9min
# [CV] min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=200, min_samples_split=50, max_depth=70, total= 1.9min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10, total=  59.3s
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10, total= 1.1min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=5, max_depth=10, total=  59.3s
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30, total=18.5min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30, total=18.4min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20
# [CV]  min_samples_leaf=2, n_estimators=1000, min_samples_split=5, max_depth=30, total=18.6min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20, total= 8.2min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70, total= 2.8min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20, total= 8.1min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70, total= 2.9min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=20, total= 8.1min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=25, max_depth=70, total= 2.9min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30, total= 3.2min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30, total= 3.2min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=30, total= 3.2min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110, total= 3.4min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90, total= 4.8min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90, total= 4.7min
# [CV] min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=10, max_depth=90, total= 4.6min
# [CV] min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20
# [CV]  min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20, total= 2.0min
# [CV] min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20
# [CV]  min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20, total= 2.0min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110, total= 3.4min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=50, max_depth=110, total= 3.4min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80
# [CV]  min_samples_leaf=25, n_estimators=350, min_samples_split=5, max_depth=20, total= 2.0min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20, total=172.8min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80, total=175.1min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80, total=175.1min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=25, max_depth=80, total=175.1min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20, total= 2.2min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=50, max_depth=20, total= 2.2min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40, total= 2.9min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40, total= 2.9min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100, total= 1.9min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=40, total= 2.9min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100, total= 2.1min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=2, max_depth=100, total= 2.1min
# [CV] min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10, total=  22.9s
# [CV] min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10, total=  22.4s
# [CV] min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=200, min_samples_split=5, max_depth=10, total=  22.3s
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100, total= 3.4min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100, total= 3.3min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=25, max_depth=100, total= 3.3min
# [CV] min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110, total= 4.8min
# [CV] min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110, total= 4.8min
# [CV] min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=110, total= 4.8min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40, total= 1.2min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40, total= 1.2min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=40, total= 1.2min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.8min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100, total= 9.8min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.8min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.8min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100, total= 9.8min
# [CV] min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30
# [CV]  min_samples_leaf=10, n_estimators=1000, min_samples_split=10, max_depth=100, total= 9.8min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30, total= 2.7min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30, total= 2.8min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60
# [CV]  min_samples_leaf=25, n_estimators=500, min_samples_split=5, max_depth=30, total= 2.8min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.4min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.5min
# [CV] min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10
# [CV]  min_samples_leaf=50, n_estimators=750, min_samples_split=2, max_depth=10, total= 1.3min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60, total=14.9min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60, total=15.0min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=2, max_depth=60, total=15.2min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100, total=11.1min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70, total= 3.7min
# [CV] min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70, total= 3.9min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=50, n_estimators=1000, min_samples_split=5, max_depth=70, total= 3.8min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100, total=11.5min
# [CV] min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=10, max_depth=100, total=11.6min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70, total= 3.9min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60, total=11.5min
# [CV] min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70, total= 3.9min
# [CV] min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60, total=11.6min
# [CV] min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70
# [CV]  min_samples_leaf=10, n_estimators=350, min_samples_split=2, max_depth=70, total= 3.9min
# [CV] min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=750, min_samples_split=5, max_depth=60, total=11.5min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70, total= 3.8min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70, total= 3.7min
# [CV] min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=2, n_estimators=200, min_samples_split=10, max_depth=70, total= 3.8min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60, total= 2.0min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70, total= 6.1min
# [CV] min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60, total= 2.1min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70, total= 6.2min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40
# [CV]  min_samples_leaf=10, n_estimators=750, min_samples_split=50, max_depth=70, total= 6.2min
# [CV] min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40
# [CV]  min_samples_leaf=10, n_estimators=200, min_samples_split=25, max_depth=60, total= 2.1min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40, total= 5.3min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40, total= 5.4min
# [CV] min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70
# [CV]  min_samples_leaf=5, n_estimators=350, min_samples_split=2, max_depth=40, total= 5.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70, total= 8.8min
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50
# [CV]  min_samples_leaf=50, n_estimators=350, min_samples_split=5, max_depth=70, total= 1.3min
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50, total= 1.9min
# [CV] min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50, total= 1.9min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=50, n_estimators=500, min_samples_split=25, max_depth=50, total= 1.9min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70, total= 8.6min
# [CV] min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50
# [CV]  min_samples_leaf=2, n_estimators=750, min_samples_split=50, max_depth=70, total= 8.6min
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50, total= 4.4min
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50, total= 3.8min
# [CV]  min_samples_leaf=25, n_estimators=750, min_samples_split=5, max_depth=50, total= 3.8min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 385.4min finished
# Best: -0.558242 using {'min_samples_leaf': 2, 'n_estimators': 1000, 'max_depth': 100, 'min_samples_split': 10}
# -0.617095 (0.002107) with: {'min_samples_leaf': 50, 'n_estimators': 500, 'max_depth': 110, 'min_samples_split': 2}
# -0.565710 (0.000931) with: {'min_samples_leaf': 5, 'n_estimators': 1000, 'max_depth': 100, 'min_samples_split': 5}
# -0.569248 (0.000806) with: {'min_samples_leaf': 2, 'n_estimators': 350, 'max_depth': 100, 'min_samples_split': 50}
# -0.615772 (0.000839) with: {'min_samples_leaf': 50, 'n_estimators': 1000, 'max_depth': 40, 'min_samples_split': 10}
# -0.569106 (0.000601) with: {'min_samples_leaf': 2, 'n_estimators': 1000, 'max_depth': 90, 'min_samples_split': 50}
# -0.615029 (0.000359) with: {'min_samples_leaf': 50, 'n_estimators': 1000, 'max_depth': 60, 'min_samples_split': 5}
# -0.566079 (0.000746) with: {'min_samples_leaf': 5, 'n_estimators': 500, 'max_depth': 30, 'min_samples_split': 5}
# -0.615025 (0.003249) with: {'min_samples_leaf': 50, 'n_estimators': 350, 'max_depth': 60, 'min_samples_split': 10}
# -0.615779 (0.003222) with: {'min_samples_leaf': 50, 'n_estimators': 350, 'max_depth': 60, 'min_samples_split': 25}
# -0.576678 (0.000447) with: {'min_samples_leaf': 10, 'n_estimators': 500, 'max_depth': 30, 'min_samples_split': 10}
# -0.578811 (0.001321) with: {'min_samples_leaf': 10, 'n_estimators': 500, 'max_depth': 70, 'min_samples_split': 25}
# -0.559440 (0.000345) with: {'min_samples_leaf': 2, 'n_estimators': 750, 'max_depth': 50, 'min_samples_split': 5}
# -0.597124 (0.000940) with: {'min_samples_leaf': 25, 'n_estimators': 200, 'max_depth': 60, 'min_samples_split': 50}
# -0.576464 (0.002483) with: {'min_samples_leaf': 10, 'n_estimators': 500, 'max_depth': 60, 'min_samples_split': 10}
# -0.558242 (0.000842) with: {'min_samples_leaf': 2, 'n_estimators': 1000, 'max_depth': 100, 'min_samples_split': 10}
# -0.573770 (0.000365) with: {'min_samples_leaf': 5, 'n_estimators': 1000, 'max_depth': 20, 'min_samples_split': 10}
# -0.560091 (0.000455) with: {'min_samples_leaf': 2, 'n_estimators': 1000, 'max_depth': 30, 'min_samples_split': 5}
# -0.575529 (0.002144) with: {'min_samples_leaf': 5, 'n_estimators': 200, 'max_depth': 70, 'min_samples_split': 50}
# -0.625998 (0.000127) with: {'min_samples_leaf': 5, 'n_estimators': 350, 'max_depth': 10, 'min_samples_split': 5}
# -0.574748 (0.000930) with: {'min_samples_leaf': 5, 'n_estimators': 750, 'max_depth': 20, 'min_samples_split': 10}
# -0.616494 (0.000287) with: {'min_samples_leaf': 50, 'n_estimators': 750, 'max_depth': 70, 'min_samples_split': 25}
# -0.576683 (0.000803) with: {'min_samples_leaf': 5, 'n_estimators': 350, 'max_depth': 30, 'min_samples_split': 50}
# -0.599064 (0.001777) with: {'min_samples_leaf': 25, 'n_estimators': 750, 'max_depth': 90, 'min_samples_split': 10}
# -0.575399 (0.000423) with: {'min_samples_leaf': 5, 'n_estimators': 350, 'max_depth': 110, 'min_samples_split': 50}
# -0.600393 (0.002238) with: {'min_samples_leaf': 25, 'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 5}
# -0.597140 (0.000340) with: {'min_samples_leaf': 25, 'n_estimators': 750, 'max_depth': 80, 'min_samples_split': 25}
# -0.588779 (0.000854) with: {'min_samples_leaf': 10, 'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 50}
# -0.598787 (0.001897) with: {'min_samples_leaf': 25, 'n_estimators': 500, 'max_depth': 40, 'min_samples_split': 5}
# -0.578391 (0.001338) with: {'min_samples_leaf': 10, 'n_estimators': 200, 'max_depth': 100, 'min_samples_split': 2}
# -0.615974 (0.000629) with: {'min_samples_leaf': 50, 'n_estimators': 1000, 'max_depth': 100, 'min_samples_split': 25}
# -0.638230 (0.001835) with: {'min_samples_leaf': 50, 'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 5}
# -0.565483 (0.001235) with: {'min_samples_leaf': 5, 'n_estimators': 350, 'max_depth': 110, 'min_samples_split': 2}
# -0.577472 (0.000230) with: {'min_samples_leaf': 10, 'n_estimators': 1000, 'max_depth': 100, 'min_samples_split': 10}
# -0.616781 (0.000334) with: {'min_samples_leaf': 50, 'n_estimators': 350, 'max_depth': 40, 'min_samples_split': 5}
# -0.628608 (0.002035) with: {'min_samples_leaf': 10, 'n_estimators': 750, 'max_depth': 10, 'min_samples_split': 2}
# -0.596839 (0.000545) with: {'min_samples_leaf': 25, 'n_estimators': 500, 'max_depth': 30, 'min_samples_split': 5}
# -0.558860 (0.001116) with: {'min_samples_leaf': 2, 'n_estimators': 750, 'max_depth': 60, 'min_samples_split': 2}
# -0.636465 (0.001085) with: {'min_samples_leaf': 50, 'n_estimators': 750, 'max_depth': 10, 'min_samples_split': 2}
# -0.564664 (0.000291) with: {'min_samples_leaf': 5, 'n_estimators': 750, 'max_depth': 100, 'min_samples_split': 10}
# -0.615524 (0.001022) with: {'min_samples_leaf': 50, 'n_estimators': 1000, 'max_depth': 70, 'min_samples_split': 5}
# -0.565559 (0.000571) with: {'min_samples_leaf': 5, 'n_estimators': 750, 'max_depth': 60, 'min_samples_split': 5}
# -0.577613 (0.001700) with: {'min_samples_leaf': 10, 'n_estimators': 350, 'max_depth': 70, 'min_samples_split': 2}
# -0.561100 (0.002637) with: {'min_samples_leaf': 2, 'n_estimators': 200, 'max_depth': 70, 'min_samples_split': 10}
# -0.582825 (0.002469) with: {'min_samples_leaf': 10, 'n_estimators': 750, 'max_depth': 70, 'min_samples_split': 50}
# -0.578023 (0.001104) with: {'min_samples_leaf': 10, 'n_estimators': 200, 'max_depth': 60, 'min_samples_split': 25}
# -0.566194 (0.001554) with: {'min_samples_leaf': 5, 'n_estimators': 350, 'max_depth': 40, 'min_samples_split': 2}
# -0.570217 (0.001371) with: {'min_samples_leaf': 2, 'n_estimators': 750, 'max_depth': 70, 'min_samples_split': 50}
# -0.616811 (0.000983) with: {'min_samples_leaf': 50, 'n_estimators': 350, 'max_depth': 70, 'min_samples_split': 5}
# -0.618178 (0.000478) with: {'min_samples_leaf': 50, 'n_estimators': 500, 'max_depth': 50, 'min_samples_split': 25}
# -0.599094 (0.001480) with: {'min_samples_leaf': 25, 'n_estimators': 750, 'max_depth': 50, 'min_samples_split': 5}

# %%
def train_random_forest():
    classifier = RandomForestClassifier(n_estimators=1000, max_depth=100, 
                                        min_samples_leaf=2, min_samples_split=10, n_jobs=-1)
    print("\nRandom Forest: Training...\n")
    classifier.fit(train_X, train_y)

    y_train_pred = classifier.predict_proba(train_X)
    print("Random Forest: Log loss on training set: %f" %log_loss(train_y, y_train_pred))

#     y_val_pred = classifier.predict_proba(X_val)
#     print("\nRandom Forest: Log loss on validation set: %f" %log_loss(y_val, y_val_pred))

    print("\nPredicting on test set...\n\n\n")
    y_test = classifier.predict_proba(test_X)

    pred_to_csv("rf", y_test, 1)
    
train_random_forest()
# Out:
# Random Forest: Training...
#
# Random Forest: Log loss on training set: 0.327016
#
# Predicting on test set...
#
#
#
#         listing_id      high       low    medium
# 10000         5529  0.000580  0.008257  0.991163
# 100013       14597  0.038811  0.137065  0.824125
# 100016       43396  0.012042  0.054109  0.933849
# 100020       25538  0.038005  0.223061  0.738935
# 100099       26644  0.017179  0.146049  0.836772
#
#
# Done! CSV for rf's predictions created!
